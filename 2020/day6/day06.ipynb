# %%
lines = [ l.replace("\n", "") for l in open('input.txt').read().split("\n\n") ]

# %%
sum_count = 0
for line in lines:
    count = len(set(line))
    sum_count += count
    
print(sum_count)
# Out:
# 6387

# %%
lines
# Out:
# ['fvki',
#  'krlugwajesizdptcvqhvwuzeicrdhpastknmozchstrwvaxkipeoudhvwzoetbdisrakxcpu',
#  'amcacmcam',
#  'ldtzbxkgpzpbkadlqxyxyzdplkb',
#  'wopvsltibzhvuirlfoqzhehzilqovmg',
#  'hilxpyvmugzbjotqsndavulgophjzidqtyasmnvoilzgnqmejswydaturph',
#  'xxx',
#  'xuhtlimyoksvqbjwzxtjzibvksuwlyhoqmvxuzsojybmhiltwkdqqwtozjmbuvyiklshxkxryhiwuvtmalbozqsj',
#  'iutvxpouixixuvkipbxu',
#  'aqogtkxotqgyivambouygqaetqgnjhrosdpacvgqomtbfwa',
#  'bfomjtvacnssmjtnabfvopmjsneafotbvvsntjmobfa',
#  'loolollool',
#  'nqfkygugykuqf',
#  'zcbcygcitc',
#  'dcwmainsjvqkrgtbpldgmawcrnklsiqvpjbtkngcwbidvjmplrtsaqrbpvswldcanjkqitgmvtglipnqsmjrbakdwc',
#  'nflmvowixltsyqkrclzphbjlznladeuhgj',
#  'qztporeajqeorlbghuavx',
#  'oarwuskqcvyxdjzfigfqrhuzvjisgwlcykodapfuqytkdagoimjrwvsczuvekgjaqsfrzcdowniy',
#  'iczbrqafnotspjluexprqblfagxuhzejw',
#  'qbkdsgdsgkbmqdgsbqrkznsgkbwixpfqdsgqkbcd',
#  'ahgjmxbkornzqvfebjpxziqfoymldhrncweta',
#  'eafmctoqtbramfkiomtgofas',
# ...

# %%
lines = [ l.split('\n') for l in open('input.txt').read().split("\n\n") ]

# %%
for l in lines:
    print(l[0].intersect(l[1],l[2]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-63daf5cb2ac2> in <module>
#       1 for l in lines:
# ----> 2     print(l[0].intersect(l[1],l[2]))
#
# AttributeError: 'str' object has no attribute 'intersect'
